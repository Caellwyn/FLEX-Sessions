# %% [markdown]
# ![ice cream flavors](images/difference-flavors-of-ice-cream.jpeg)
#
#
# # Let's analyze ice cream flavor reviews in Pandas!
#
# We are working on analyzing reviews of ice cream flavors to help retailers decide which flavors to carry and give feedback to manufacturers on how well each flavor is being received.
#
# In a previous session we joined two tables and removed missing data.  In this session we will:
#
# 1. Examine summary statistics about numeric values in a dataframe
# 2. Group a dataframe by one feature and examine statistics of each category in that feature
# 3. Analyze and draw conclusions about those statistics

# %% [markdown]
# # 1. Import Modules
#
# Import Pandas as 'pd'

# %%
#__SOLUTION__

import pandas as pd

# %% [markdown]
# # 2. Load the Data
#
# Load the table called 'icecream.csv' into a pandas dataframe named 'icecream' and display the first 5 rows

# %%
#__SOLUTION__

icecream = pd.read_csv('icecream.csv')
icecream.head(5)
# Out:
#      key                 author        date  stars  helpful_yes  helpful_no  \
# 0  10_bj        Flavor Reviewer  2017-04-12      5            5           3
# 1  10_bj  Americone Dream Lover  2017-04-27      5           15           3
# 2  10_bj            KellyCrayon  2017-05-13      5            0           1
# 3  10_bj                 Ana808  2017-06-13      3            1           1
# 4  10_bj           Jennibobunni  2017-06-14      5            0           0
#
#                                                 text              name  \
# 0  Excellent! This flavor has all sorts of things...  Americone Dream®
# 1  I eat a pint when I am sad, I eat a pint when ...  Americone Dream®
# 2  My absolute favorite of all of Ben and Jerry's...  Americone Dream®
# 3  I decided to go with something out of the blue...  Americone Dream®
# 4  My favorite ice cream in this world! For a lon...  Americone Dream®
#
#                                              subhead  \
# 0  Vanilla Ice Cream with Fudge-Covered Waffle Co...
# 1  Vanilla Ice Cream with Fudge-Covered Waffle Co...
# 2  Vanilla Ice Cream with Fudge-Covered Waffle Co...
# 3  Vanilla Ice Cream with Fudge-Covered Waffle Co...
# 4  Vanilla Ice Cream with Fudge-Covered Waffle Co...
#
#                                          description  rating  rating_count  \
# 0  Founded in fudge-covered waffle cones, this ca...     4.7           370
# 1  Founded in fudge-covered waffle cones, this ca...     4.7           370
# 2  Founded in fudge-covered waffle cones, this ca...     4.7           370
# 3  Founded in fudge-covered waffle cones, this ca...     4.7           370
# 4  Founded in fudge-covered waffle cones, this ca...     4.7           370
#
#                                          ingredients
# 0  CREAM, SKIM MILK, LIQUID SUGAR (SUGAR, WATER),...
# 1  CREAM, SKIM MILK, LIQUID SUGAR (SUGAR, WATER),...
# 2  CREAM, SKIM MILK, LIQUID SUGAR (SUGAR, WATER),...
# 3  CREAM, SKIM MILK, LIQUID SUGAR (SUGAR, WATER),...
# 4  CREAM, SKIM MILK, LIQUID SUGAR (SUGAR, WATER),...

# %% [markdown]
# # Quick look at the statistics of the data
#
# Display a data frame showing the following for each numeric column:
# 1. The maximum and minimum values
# 2. The thresholds of each quartile
# 3. The mean and standard deviation
#
# (Can you do this in one method?)

# %%
#__SOLUTION__

icecream.describe()
# Out:
#              stars  helpful_yes   helpful_no       rating  rating_count
# count  7659.000000  7659.000000  7659.000000  7659.000000   7659.000000
# mean      4.297820     0.989555     0.523698     4.304178    378.691344
# std       1.322292     3.734447     2.626990     0.619601    339.474514
# min       1.000000     0.000000     0.000000     1.800000      7.000000
# 25%       4.000000     0.000000     0.000000     4.100000    111.000000
# 50%       5.000000     0.000000     0.000000     4.600000    208.000000
# 75%       5.000000     1.000000     0.000000     4.700000    639.000000
# max       5.000000   105.000000    86.000000     5.000000    983.000000

# %% [markdown]
# Write 3 interesting observations about this statistical analysis and make a hypothesis about each one.
#
# These don't have to be complicated or profound...but can be!

# %%
# Type your observations here:

# Observation 1:

# Hypthothesis 1:

# Observation 2:

# Hypothesis 2:

# Observation 3:

# Hypthothesis 3:

# %% [markdown]
# Are there any columns that look like they may have a lot of placeholder values and very little useful data?  If so, remove those columns below.

# %%
#__SOLUTION__


icecream = icecream.drop(['helpful_yes', 'helpful_no'], axis=1)
icecream.columns
# Out:
# Index(['key', 'author', 'date', 'stars', 'text', 'name', 'subhead',
#        'description', 'rating', 'rating_count', 'ingredients'],
#       dtype='object')

# %% [markdown]
# Our manufacturers want to know how many reviews each flavor has, as well.
#
# Group the reviews by flavor and count how many are in each group.  Then sort them from most reviews to least.

# %% [markdown]
# # Statistics by flavor
#
# Above we examined statistics about the entire dataset.  Now let's start collecting some statistics about each flavor.  To do this, let's make a new dataframe to hold stats the stats.
# Create a new dataframe called 'icecream_stats' and set the index to the unique names of the flavors of icecream in 'icecream' and the columns to 'num_reviews', 'mean_rating', and 'std'.

# %%
#__SOLUTION__


flavors = icecream['name'].unique()

icecream_stats = pd.DataFrame(index=flavors, columns = ['num_ratings', 'mean_rating', 'rating_std'])
icecream_stats
# Out:
#                                      num_ratings mean_rating rating_std
# Americone Dream®                             NaN         NaN        NaN
# Berry Sweet Mascarpone                       NaN         NaN        NaN
# Boom Chocolatta™ Cookie Core                 NaN         NaN        NaN
# Boots on the Moooo’n™                        NaN         NaN        NaN
# Bourbon Pecan Pie                            NaN         NaN        NaN
# Brewed to Matter™                            NaN         NaN        NaN
# Brownie Batter Core                          NaN         NaN        NaN
# Cannoli                                      NaN         NaN        NaN
# Caramel Chocolate Cheesecake                 NaN         NaN        NaN
# Cherry Garcia®                               NaN         NaN        NaN
# Chillin' the Roast™                          NaN         NaN        NaN
# Chip Happens                                 NaN         NaN        NaN
# Chocolate Chip Cookie Dough                  NaN         NaN        NaN
# Chocolate Chip Cookie Dough Core             NaN         NaN        NaN
# Chocolate Fudge Brownie                      NaN         NaN        NaN
# Chocolate Peanut Butter Split                NaN         NaN        NaN
# Chocolate Shake It™                          NaN         NaN        NaN
# Chocolate Therapy®                           NaN         NaN        NaN
# Chubby Hubby®                                NaN         NaN        NaN
# Chunky Monkey®                               NaN         NaN        NaN
# Cinnamon Buns®                               NaN         NaN        NaN
# Coffee Coffee BuzzBuzzBuzz!®                 NaN         NaN        NaN
# Coffee Toffee Bar Crunch                     NaN         NaN        NaN
# Cold Brew Caramel Latte                      NaN         NaN        NaN
# Cookies & Cream Cheesecake Core              NaN         NaN        NaN
# Everything But The...®                       NaN         NaN        NaN
# Gimme S’more!™                               NaN         NaN        NaN
# Glampfire Trail Mix™                         NaN         NaN        NaN
# Half Baked®                                  NaN         NaN        NaN
# Ice Cream Sammie                             NaN         NaN        NaN
# Justice ReMix'd ™                            NaN         NaN        NaN
# Karamel Sutra® Core                          NaN         NaN        NaN
# Milk & Cookies                               NaN         NaN        NaN
# Mint Chocolate Cookie                        NaN         NaN        NaN
# Minter Wonderland™                           NaN         NaN        NaN
# Netflix & Chilll'd™                          NaN         NaN        NaN
# New York Super Fudge Chunk®                  NaN         NaN        NaN
# Oat of This Swirled™                         NaN         NaN        NaN
# Peanut Butter Cup                            NaN         NaN        NaN
# Peanut Butter Fudge Core                     NaN         NaN        NaN
# Peanut Butter Half Baked®                    NaN         NaN        NaN
# Peanut Butter World®                         NaN         NaN        NaN
# Phish Food®                                  NaN         NaN        NaN
# Pistachio Pistachio                          NaN         NaN        NaN
# Pumpkin Cheesecake                           NaN         NaN        NaN
# Red, White & Blueberry                       NaN         NaN        NaN
# S'mores                                      NaN         NaN        NaN
# Salted Caramel Almond                        NaN         NaN        NaN
# Salted Caramel Core                          NaN         NaN        NaN
# Strawberry Cheesecake                        NaN         NaN        NaN
# Sweet Like Sugar Cookie Dough Core           NaN         NaN        NaN
# The Tonight Dough®                           NaN         NaN        NaN
# Triple Caramel Chunk®                        NaN         NaN        NaN
# Urban Bourbon™                               NaN         NaN        NaN
# Vanilla                                      NaN         NaN        NaN
# Vanilla Caramel Fudge                        NaN         NaN        NaN
# Wake & " No Bake " Cookie Dough Core         NaN         NaN        NaN

# %% [markdown]
# Now, create a groupby object that groups the 'icecream' dataframe by 'name'.

# %%
#__SOLUTION__


name_groups = icecream.groupby(by='name')
name_groups

# %% [markdown]
# Now set each column of the 'icecream_stats' dataframe to a different statistic describing each flavor:
#
# Set 'num_ratings' to the number of ratings of each flavor.
#
# Set 'mean_rating' to the mean number of stars each flavor got.
#
# Set 'rating_std' to the standard deviation of the number of stars each flavor got.

# %%
#__SOLUTION__


icecream_stats['num_ratings'] = name_groups.count()
icecream_stats['mean_rating'] = name_groups.mean()
icecream_stats['rating_std'] = name_groups.std()
icecream_stats
# Out:
#                                       num_ratings  mean_rating  rating_std
# Americone Dream®                              354     4.742938    0.676617
# Berry Sweet Mascarpone                         10     4.600000    1.264911
# Boom Chocolatta™ Cookie Core                   94     4.563830    0.945374
# Boots on the Moooo’n™                          41     4.731707    0.975305
# Bourbon Pecan Pie                               9     4.555556    1.333333
# Brewed to Matter™                              35     4.742857    0.657216
# Brownie Batter Core                           107     3.485981    1.436482
# Cannoli                                        69     3.652174    1.670031
# Caramel Chocolate Cheesecake                  130     4.007692    1.491558
# Cherry Garcia®                                149     4.416107    1.257951
# Chillin' the Roast™                           171     3.345029    1.756740
# Chip Happens                                  128     4.664062    1.013898
# Chocolate Chip Cookie Dough                   927     4.554477    0.957520
# Chocolate Chip Cookie Dough Core              161     1.844720    1.296915
# Chocolate Fudge Brownie                       197     3.360406    1.797690
# Chocolate Peanut Butter Split                   5     5.000000    0.000000
# Chocolate Shake It™                           109     3.844037    1.534627
# Chocolate Therapy®                             71     4.760563    0.783122
# Chubby Hubby®                                 116     4.275862    1.255154
# Chunky Monkey®                                104     4.461538    1.122783
# Cinnamon Buns®                                 82     4.609756    1.062911
# Coffee Coffee BuzzBuzzBuzz!®                   45     4.844444    0.601345
# Coffee Toffee Bar Crunch                      293     2.887372    1.915406
# Sweet Like Sugar Cookie Dough Core            119     4.781513    0.771963
# Chubby Hubby®                                 116     4.275862    1.255154
# Chocolate Shake It™                           109     3.844037    1.534627
# Brownie Batter Core                           107     3.485981    1.436482
# Justice ReMix'd ™                             106     4.311321    1.423364
# Chunky Monkey®                                104     4.461538    1.122783
# Milk & Cookies                                102     4.735294    0.843454
# Boom Chocolatta™ Cookie Core                   94     4.563830    0.945374
# Karamel Sutra® Core                            93     4.204301    1.016806
# Phish Food®                                    91     4.835165    0.619386
# Cinnamon Buns®                                 82     4.609756    1.062911
# Pistachio Pistachio                            75     3.986667    1.631558
# Everything But The...®                         72     3.791667    1.528485
# Chocolate Therapy®                             71     4.760563    0.783122
# Cannoli                                        69     3.652174    1.670031
# Glampfire Trail Mix™                           68     4.720588    0.825807
# Peanut Butter World®                           68     4.852941    0.717889
# Wake & " No Bake " Cookie Dough Core           63     3.238095    1.747942
# New York Super Fudge Chunk®                    63     4.904762    0.465392
# Cookies & Cream Cheesecake Core                56     4.339286    1.283132
# Pumpkin Cheesecake                             56     4.607143    1.021204
# Coffee Coffee BuzzBuzzBuzz!®                   45     4.844444    0.601345
# Boots on the Moooo’n™                          41     4.731707    0.975305
# Peanut Butter Cup                              40     4.400000    1.127739
# Red, White & Blueberry                         38     3.394737    1.636401
# Brewed to Matter™                              35     4.742857    0.657216
# Minter Wonderland™                             32     4.718750    0.991394
# Ice Cream Sammie                               31     4.967742    0.179605
# Vanilla Caramel Fudge                          26     4.730769    0.961569
# Salted Caramel Almond                          23     4.521739    1.274561
# Peanut Butter Fudge Core                       19     4.736842    0.805682
# Triple Caramel Chunk®                          16     4.312500    1.302242
# Peanut Butter Half Baked®                      14     4.928571    0.267261
# Cold Brew Caramel Latte                        10     4.600000    1.264911
# Berry Sweet Mascarpone                         10     4.600000    1.264911
# Vanilla                                         9     4.666667    1.000000
# Bourbon Pecan Pie                               9     4.555556    1.333333
# Chocolate Peanut Butter Split                   5     5.000000    0.000000

# %%
# Is our hypothesis correct?

#

# %% [markdown]
# If you haven't already, check the correlations between the mean ratings, number of ratings, and standard deviation of the ratings.  Are any of them correlated?

# %%
#__SOLUTION__

icecream_stats.corr()
# Out:
#              num_ratings  mean_rating  rating_std
# num_ratings     1.000000    -0.038854    0.003156
# mean_rating    -0.038854     1.000000   -0.753064
# rating_std      0.003156    -0.753064    1.000000

# %%
#__SOLUTION__


# Are there any strong correlations between these statistics?  What does this chart tell you?

# There is a strong negative correlation between std and mean rating.
# This tells me that the more popular a flavor is, the more often reviewers agree on the rating.
#

# %% [markdown]
# # Summary

# %%
# Based on our analysis so far, which 5 icecream flavors do you think retailers should stock?

#
#
#

# Are their any flavors that manufacturers should consider discontinuing?  If so, which ones?

#
#
#

# %% [markdown]
# # Conclusion:
#
# In this notebook you:
# 1. Examined summary statistics about a dataframe and used them to make choices about feature selection.
# 2. Created a new dataframe
# 3. Grouped a dataframe by a feature
# 4. Returned statistics about categories in a feature
# 5. Examined correlations between features
# 6. Used your statistical analysis to make a recommendation to stakeholders.
